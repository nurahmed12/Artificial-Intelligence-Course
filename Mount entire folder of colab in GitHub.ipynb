# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/MyDrive"
# Out:
# 'Artificial Intelligence Presentation Slide'
# 'Assignment 2 (1).docx'
# 'Assignment 2.docx'
# 'Assignment cover page for ruba.pdf'
# 'Assignment cover page.pdf'
# 'Assignment SE 323'
# 'bqo-kkoy-ovg - Nov 23, 2023.gjam'
# 'bqo-kkoy-ovg - Nov 23, 2023.pdf'
# 'Call for video presentation'
#  Classroom
# 'Colab Notebooks'
#  Crack.zip
#  CV.pdf
# 'CV Resume'
#  dragon_ball_super_game
# 'English presentation 1(Final edit).pptx'
# 'Final Assignment (Project).pdf'
#  For
# 'Formal Photo'
# 'For sharing'
#  Fun
# 'HOW TO ACTIVATE!!!.txt'
#  inbound4385292972637489618.jpg
# 'Intelligent weight prediction of cows based on semantic segmentation and back propagation neural network.pdf'
# 'Introduction to Machine Learning Presentation Slide'
# 'Intro Pesentation 1.pptx'
# 'Lab Report Upload'
# 'Makeup Assignment for Quiz 3.pdf'
# 'Management Information System Presentation'
# 'Math 101 presentation'
# 'Md Razib.gsite'
# 'MIS Assignment'
# 'Nur Ahmed (222-35-1111)'
# 'OOC 3rd Quiz'
# ...

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks"
# Out:
#  222-35-1111.ipynb			     AI_Lab_Class_1.ipynb
# 'Additional Lab Class on Matplotlib.ipynb'   AI_Lab_Class_2.ipynb
# 'Additional Lab on Pandas.ipynb'	     Artificial-Intelligence-Course
# 'AI_Lab_13 02 2025.ipynb'		     Lab_Task_Basic_Python_Code.ipynb
# 'AI_Lab_22 02 2025.ipynb'		    'Mount entire folder of colab in GitHub.ipynb'
# 'AI_Lab_22 03 2025.ipynb'		     Untitled0.ipynb
# 'AI_Lab_class_12 02 2025.ipynb'

# %%
colab_folder_path = "/content/drive/MyDrive/Colab Notebooks/"

# %%
import os
os.chdir(colab_folder_path)
# !pwd
# !ls *.ipynb
# Out:
# /content/drive/MyDrive/Colab Notebooks
#  222-35-1111.ipynb			    'AI_Lab_class_12 02 2025.ipynb'
# 'Additional Lab Class on Matplotlib.ipynb'   AI_Lab_Class_1.ipynb
# 'Additional Lab on Pandas.ipynb'	     AI_Lab_Class_2.ipynb
# 'AI_Lab_13 02 2025.ipynb'		     Lab_Task_Basic_Python_Code.ipynb
# 'AI_Lab_22 02 2025.ipynb'		    'Mount entire folder of colab in GitHub.ipynb'
# 'AI_Lab_22 03 2025.ipynb'		     Untitled0.ipynb

# %%
# GitHub Personal Access Token and repo info
token = "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"
repo_name = "Artificial-Intelligence-Course"
repo_url = f"https://{token}@github.com/nurahmed12/{repo_name}.git"

# %%
# Clone the repo
# !git clone {repo_url}
# Out:
# fatal: destination path 'Artificial-Intelligence-Course' already exists and is not an empty directory.

# %%
# Copy all notebooks into the repo folder
# !cp *.ipynb {repo_name}/
# Change to the repo directory
os.chdir(f"{colab_folder_path}/{repo_name}")
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/Artificial-Intelligence-Course

# %%
# Re-set the remote URL to include your token (critical for pushing)
# !git remote set-url origin {repo_url}

# %%
# Configure Git and push
# !git config --global user.email "officialme.nurahmed@gmail.com"
# !git config --global user.name "Nur Ahmed"

# !git add .
# !git commit -m "Add multiple Colab notebooks"
# !git push origin main
# Out:
# [main 83120f0] Add multiple Colab notebooks
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Mount entire folder of colab in GitHub.ipynb (74%)
# remote: Permission to nurahmed12/Artificial-Intelligence-Course.git denied to nurahmed12.
# fatal: unable to access 'https://github.com/nurahmed12/Artificial-Intelligence-Course.git/': The requested URL returned error: 403
