# %% [markdown]
# **Operations**

# %%
# Addition
a = 10
b = 20
c = a + b
print(c)

# %%
12 + 34

# %%
# Multiplicataion
2 * 3

# %%
# Division
1/2

# %%
# Exponent
2 ** 4

# %%
# Module
11 % 3

# %%
(2 + 3) * (5 + 5)

# %% [markdown]
# **Variable Assignment**

# %%
x = 2
y = 5
x + y

# %%
print(x + y)

# %%
z = x * y

# %%
print(z)

# %% [markdown]
# **String**

# %%
x = 'Hello dudes '
print(x)

# %%
y = 'of SWE'
print(x + y)

# %%
z = x + y

# %%
len(z)

# %%
b = "sup bro's?"
b

# %%
print(b)

# %%
age = 24
name = 'Nur'

# %% [markdown]
# **Format Printing**

# %%
print(f"My name is {name}, and I am {age} years old.")

# %%
print("My name is {}, and I am {} years old.".format(name, age))

# %%
print("My name is {var1}, and I am {var2} years old.".format(var1 = name, var2 = age))

# %%
name = 'Sam'
id = 201343
section = '38_B'

# %%
print(f"My name is {name}, id = {id}, and Section = {section}")

# %% [markdown]
# **List**: Ordered, mutable, can have duplicates.

# %%
a = [1, 34, 44, 3, 1, 555]
print(a)

# %%
for i in a:
  print(i)

# %%
a[4]

# %%
a[4] + a[5]

# %%
b = [1, 3, 5, [45, 56, 66]]

# %%
print(b)

# %%
for i in b:
  if type(i) == list:
    for j in i:
      print(j)
  else:
    print(i)

# %%
b[3][1]

# %%
b[1 : ]

# %%
a[2 : 4]

# %%
b[1] = 3455
b

# %%
c = [1, 2, 3, [2, 54, 23]]

# %%
print(c[1 : ])

# %%
d = ['a', 'b', 'c']
d

# %%
d.append('d')
d
