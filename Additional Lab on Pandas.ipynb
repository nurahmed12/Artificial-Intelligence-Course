# %%
# Import Pandas Library
import pandas as pd

# %%
df = pd.read_excel('YTcomments1.xlsx')

# %%
# Top 5 rows
df.head()
# Out:
#    Unnamed: 0          publish_date            channel_name  \
# 0         NaN  2025-02-05T12:59:35Z  Independent Television
# 1         NaN  2025-02-05T12:59:35Z  Independent Television
# 2         NaN  2025-02-05T12:59:35Z  Independent Television
# 3         NaN  2025-02-05T12:59:35Z  Independent Television
# 4         NaN  2025-02-05T12:59:35Z  Independent Television
#
#                                          video_title  \
# 0  জুলাই হ/ত্যাকাণ্ডের বিচার না হলে ভবিষ্যতে আরও ...
# 1  জুলাই হ/ত্যাকাণ্ডের বিচার না হলে ভবিষ্যতে আরও ...
# 2  জুলাই হ/ত্যাকাণ্ডের বিচার না হলে ভবিষ্যতে আরও ...
# 3  জুলাই হ/ত্যাকাণ্ডের বিচার না হলে ভবিষ্যতে আরও ...
# 4  জুলাই হ/ত্যাকাণ্ডের বিচার না হলে ভবিষ্যতে আরও ...
#
#                                      video_url  \
# 0  https://www.youtube.com/watch?v=0MmU44Tx6Dk
# 1  https://www.youtube.com/watch?v=0MmU44Tx6Dk
# 2  https://www.youtube.com/watch?v=0MmU44Tx6Dk
# 3  https://www.youtube.com/watch?v=0MmU44Tx6Dk
# ...

# %%
# Number of rows for a specific column
df.text.value_counts().sum()

# %%
# Total number of rows and columns
df.shape

# %%
# Shows the datatypes of each column
df.dtypes

# %%
# Show last 5 rows
df.tail()

# %%
# Shows random 5 rows
df.sample(5)

# %%
# Shows column names
df.columns

# %%
# Changing column names
df.rename(columns={'text': 'Comments', 'likes': 'Likes'}, inplace=True)

# %%
df.tail()

# %%
# Deletes a column
df.drop(columns=['video_url'], inplace=True)

# %%
df.head()

# %%
# Adds a new column with values
df['Section'] = '38A'
df.head()

# %%
# Iterate through a DataFrame
for index, row in df.iterrows():
    print(index, row.Comments)
